# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv('27102020_acc1_2.csv')

# df.to_numpy()
x = df.iloc[:,2::2]
y = df.iloc[:,1::2]

x

# data = df.plot(x='timestamp')
# data.set_xlabel("RTU Value")
# Out:
#              0  -0.036541859       0.1  0.073083718  -0.073083718  \
# 0     0.036542      0.073084 -0.401960    -0.036542      0.182709
# 1    -0.036542      0.036542  0.036542    -0.036542      0.036542
# 2     0.000000      0.000000  0.000000     0.000000      0.000000
# 3     0.000000     -0.036542  0.000000     0.000000      0.000000
# 4     0.000000      0.000000  0.000000     0.000000      0.000000
# ...        ...           ...       ...          ...           ...
# 4952 -0.036542      0.000000  0.036542     0.000000     -0.073084
# 4953 -0.036542      0.073084 -0.036542     0.000000      0.000000
# 4954  0.182709     -0.328877  0.073084     0.146167     -0.401960
# 4955 -0.073084      0.182709 -0.036542    -0.036542      0.000000
# 4956  0.000000      0.000000 -0.036542     0.000000      0.000000
#
#       -0.073083718.1  0.073083718.1  -0.036541859.1  -0.073083718.2  \
# 0           0.182709      -0.328877        0.182709        0.073084
# 1           0.000000       0.073084        0.036542        0.000000
# 2           0.000000       0.000000        0.000000        0.000000
# 3           0.000000      -0.036542        0.000000        0.036542
# 4           0.000000       0.036542        0.000000        0.000000
# ...              ...            ...             ...             ...
# 4952        0.036542       0.000000       -0.073084        0.036542
# 4953        0.000000       0.000000       -0.073084        0.073084
# 4954        0.182709      -0.401960       -0.328877        0.146167
# 4955        0.073084      -0.073084       -0.036542        0.073084
# 4956       -0.036542       0.000000        0.000000        0.000000
#
#       0.073083718.2  ...  0.036541859.17      0.48  -0.073083718.18      0.50  \
# 0         -0.328877  ...       -0.401960  0.000000         0.146167 -0.328877
# 1          0.036542  ...        0.000000  0.000000         0.000000  0.000000
# 2          0.000000  ...        0.000000  0.000000         0.000000 -0.036542
# 3          0.000000  ...        0.000000  0.000000         0.000000  0.000000
# 4          0.000000  ...        0.000000 -0.036542         0.000000  0.000000
# ...             ...  ...             ...       ...              ...       ...
# 4952       0.000000  ...       -0.073084  0.000000         0.000000 -0.036542
# 4953       0.000000  ...        0.000000  0.000000         0.036542 -0.073084
# 4954      -0.401960  ...       -0.401960  0.000000         0.182709  0.000000
# 4955       0.036542  ...        0.000000  0.000000        -0.036542  0.000000
# 4956      -0.073084  ...        0.000000  0.000000         0.036542  0.000000
#
#           0.52  -0.073083718.19  -0.073083718.20  0.073083718.13      0.54  \
# 0     0.000000         0.036542         0.182709       -0.328877  0.000000
# 1     0.073084        -0.073084         0.000000        0.000000  0.000000
# 2     0.000000         0.000000         0.000000        0.000000  0.000000
# 3     0.036542         0.000000         0.000000        0.000000  0.000000
# 4    -0.036542         0.000000         0.000000        0.000000  0.000000
# ...        ...              ...              ...             ...       ...
# 4952  0.036542         0.000000        -0.036542        0.000000  0.036542
# 4953  0.036542         0.000000         0.000000       -0.036542 -0.073084
# 4954 -0.401960         0.146167         0.073084       -0.328877  0.146167
# 4955  0.000000         0.000000        -0.073084        0.036542 -0.036542
# 4956 -0.073084         0.000000         0.036542        0.000000  0.000000
#
#       -0.073083718.21
# 0            0.182709
# 1           -0.036542
# 2            0.000000
# 3            0.000000
# 4            0.000000
# ...               ...
# 4952         0.000000
# 4953         0.036542
# 4954        -0.036542
# 4955        -0.036542
# 4956         0.000000
#
# [4957 rows x 100 columns]

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import math
fileName = "acc02.csv"
with open(fileName) as fileData:
            X,Y,timestamps = [],[],[]
            for row in fileData:
                rawData = row.replace('\n','').split(',')
                timestamp = (rawData.pop(0))
                for index in range(len(rawData)):
                    timestamps.append(timestamp)
                    if int(index) % 2 == 0:
                        X.append(float(rawData[index]))
                    else:
                        Y.append(float(rawData[index]))
            df = DataFrame({
                'Time': timestamps,
                'Lintang': X,
                'Vertikal':Y
            })
            df.plot(x='Time', subplots=True, layout=(2, 1), sharey=True)
            plt.title(arguments[2].replace('_', ' ').replace('.csv', ''))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-8e1fea83ae5c> in <module>
#      16                     else:
#      17                         Y.append(float(rawData[index]))
# ---> 18             df = DataFrame({
#      19                 'Time': timestamps,
#      20                 'Lintang': X,
#
# e:\werk\venv\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# e:\werk\venv\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# e:\werk\venv\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# e:\werk\venv\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     363             lengths = list(set(raw_lengths))
#     364             if len(lengths) > 1:
# --> 365                 raise ValueError("arrays must all be same length")
#     366
#     367             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
df1 = pd.read_csv('27102020_strain.csv')
x = df1.iloc[:,2::]
x
# Out:
#        62.18.1  62.18.2  62.18.3  62.18.4  62.18.5  62.18.6  62.18.7  62.18.8  \
# 0        62.22    62.22    62.22    62.22    62.22    62.22    62.22    62.22
# 1        62.16    62.16    62.16    62.16    62.16    62.16    62.16    62.16
# 2        62.15    62.15    62.15    62.15    62.15    62.15    62.15    62.15
# 3        62.19    62.19    62.19    62.19    62.19    62.19    62.19    62.19
# 4        62.17    62.17    62.17    62.17    62.17    62.17    62.17    62.17
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 49444    55.43    55.43    55.43    55.43    55.43    55.43    55.43    55.43
# 49445    55.45    55.45    55.45    55.45    55.45    55.45    55.45    55.45
# 49446    55.47    55.47    55.47    55.47    55.47    55.47    55.47    55.47
# 49447    55.54    55.54    55.54    55.54    55.54    55.54    55.54    55.54
# 49448    55.48    55.48    55.48    55.48    55.48    55.48    55.48    55.48
#
#        62.18.9  62.18.10  ...  62.18.90  62.18.91  62.18.92  62.18.93  \
# 0        62.22     62.22  ...     62.22     62.22     62.22     62.22
# 1        62.16     62.16  ...     62.16     62.16     62.16     62.16
# 2        62.15     62.15  ...     62.15     62.15     62.15     62.15
# 3        62.19     62.19  ...     62.19     62.19     62.19     62.19
# 4        62.17     62.17  ...     62.17     62.17     62.17     62.17
# ...        ...       ...  ...       ...       ...       ...       ...
# 49444    55.43     55.43  ...     55.43     55.43     55.43     55.43
# 49445    55.45     55.45  ...     55.45     55.45     55.45     55.45
# 49446    55.47     55.47  ...     55.47     55.47     55.47     55.47
# 49447    55.54     55.54  ...     55.54     55.54     55.54     55.54
# 49448    55.48     55.48  ...     55.48     55.48     55.48     55.48
#
#        62.18.94  62.18.95  62.18.96  62.18.97  62.18.98  62.18.99
# 0         62.22     62.22     62.22     62.22     62.22     62.22
# 1         62.16     62.16     62.16     62.16     62.16     62.16
# 2         62.15     62.15     62.15     62.15     62.15     62.15
# 3         62.19     62.19     62.19     62.19     62.19     62.19
# 4         62.17     62.17     62.17     62.17     62.17     62.17
# ...         ...       ...       ...       ...       ...       ...
# 49444     55.43     55.43     55.43     55.43     55.43     55.43
# 49445     55.45     55.45     55.45     55.45     55.45     55.45
# 49446     55.47     55.47     55.47     55.47     55.47     55.47
# 49447     55.54     55.54     55.54     55.54     55.54     55.54
# 49448     55.48     55.48     55.48     55.48     55.48     55.48
#
# [49449 rows x 99 columns]

# %%
import pandas as pd 
from pandas.plotting import autocorrelation_plot
import numpy as np
df = pd.read_csv('yes.csv')
df.set_index("line")
for variable in df.columns:
    ax = autocorrelation_plot(df[variable])

ax.set_xlim([0, 1190])
ax.legend(ax.get_lines())

# %%
d1 = pd.read_csv('yes.csv')
def df_autocorr(df, lag, axis=0):
    """Compute full-sample column-wise autocorrelation for a DataFrame."""
    return df.apply(lambda col: col.autocorr(lag), axis=axis)

for i in range(110): 
    print(df_autocorr(d1,i))
# print('Mean:', np.mean(d1))
# Out:
# line    1.0
# dtype: float64
# line    0.928519
# dtype: float64
# line    0.914755
# dtype: float64
# line    0.913163
# dtype: float64
# line    0.910778
# dtype: float64
# line    0.904934
# dtype: float64
# line    0.89668
# dtype: float64
# line    0.894285
# dtype: float64
# line    0.891157
# dtype: float64
# line    0.887286
# dtype: float64
# line    0.8776
# dtype: float64
# line    0.879104
# dtype: float64
# line    0.873601
# dtype: float64
# line    0.868511
# dtype: float64
# line    0.862958
# dtype: float64
# line    0.863226
# dtype: float64
# line    0.857597
# dtype: float64
# line    0.85354
# dtype: float64
# line    0.850093
# dtype: float64
# line    0.843059
# dtype: float64
# line    0.840488
# dtype: float64
# line    0.844961
# dtype: float64
# line    0.83655
# dtype: float64
# line    0.835274
# dtype: float64
# line    0.828116
# dtype: float64
# line    0.825645
# dtype: float64
# line    0.823125
# dtype: float64
# line    0.812762
# dtype: float64
# line    0.811421
# dtype: float64
# line    0.815004
# dtype: float64
# line    0.806819
# dtype: float64
# line    0.804363
# dtype: float64
# line    0.803103
# dtype: float64
# line    0.795801
# dtype: float64
# line    0.795793
# dtype: float64
# line    0.793954
# dtype: float64
# line    0.79092
# dtype: float64
# line    0.788205
# dtype: float64
# line    0.785381
# dtype: float64
# line    0.784927
# dtype: float64
# line    0.777404
# dtype: float64
# line    0.776368
# dtype: float64
# line    0.772611
# dtype: float64
# line    0.771051
# dtype: float64
# line    0.770687
# dtype: float64
# line    0.763295
# dtype: float64
# line    0.761435
# dtype: float64
# line    0.761921
# dtype: float64
# line    0.754672
# dtype: float64
# line    0.751898
# dtype: float64
# line    0.748286
# dtype: float64
# line    0.741104
# dtype: float64
# line    0.738568
# dtype: float64
# line    0.734275
# dtype: float64
# line    0.73109
# dtype: float64
# line    0.724218
# dtype: float64
# line    0.71977
# dtype: float64
# line    0.715417
# dtype: float64
# line    0.708317
# dtype: float64
# line    0.702965
# dtype: float64
# line    0.702164
# dtype: float64
# line    0.693208
# dtype: float64
# line    0.691983
# dtype: float64
# line    0.682016
# dtype: float64
# line    0.682176
# dtype: float64
# line    0.676732
# dtype: float64
# line    0.673206
# dtype: float64
# line    0.668032
# dtype: float64
# line    0.665296
# dtype: float64
# line    0.657834
# dtype: float64
# line    0.647984
# dtype: float64
# line    0.647136
# dtype: float64
# line    0.642282
# dtype: float64
# line    0.637392
# dtype: float64
# line    0.633622
# dtype: float64
# line    0.635163
# dtype: float64
# line    0.626117
# dtype: float64
# line    0.624695
# dtype: float64
# line    0.623884
# dtype: float64
# line    0.619969
# dtype: float64
# line    0.613706
# dtype: float64
# line    0.606779
# dtype: float64
# line    0.604956
# dtype: float64
# line    0.600609
# dtype: float64
# line    0.592659
# dtype: float64
# line    0.590967
# dtype: float64
# line    0.59022
# dtype: float64
# line    0.583526
# dtype: float64
# line    0.579935
# dtype: float64
# line    0.579921
# dtype: float64
# line    0.57372
# dtype: float64
# line    0.569388
# dtype: float64
# line    0.566247
# dtype: float64
# line    0.564974
# dtype: float64
# line    0.560877
# dtype: float64
# line    0.557773
# dtype: float64
# line    0.555554
# dtype: float64
# line    0.553448
# dtype: float64
# line    0.55069
# dtype: float64
# line    0.543004
# dtype: float64
# line    0.54381
# dtype: float64
# line    0.540218
# dtype: float64
# line    0.530744
# dtype: float64
# line    0.524827
# dtype: float64
# line    0.522348
# dtype: float64
# line    0.518863
# dtype: float64
# line    0.515465
# dtype: float64
# line    0.507696
# dtype: float64
# line    0.500294
# dtype: float64
# line    0.495315
# dtype: float64

# %%
# importing pandas as pd 
import pandas as pd 

# Creating the Series 
sr = pd.Series([11, 21, 8, 18, 65, 18, 32, 10, 5, 32, None]) 

# Create the Index 
index_ = pd.date_range('2010-10-09 08:45', periods = 11, freq ='H') 

# set the index 
sr.index = index_ 

# Print the series 
print(sr) 

# return the auto correlation 
result = sr.autocorr() 

# Print the result 
print(result)
# Out:
# 2010-10-09 08:45:00    11.0
# 2010-10-09 09:45:00    21.0
# 2010-10-09 10:45:00     8.0
# 2010-10-09 11:45:00    18.0
# 2010-10-09 12:45:00    65.0
# 2010-10-09 13:45:00    18.0
# 2010-10-09 14:45:00    32.0
# 2010-10-09 15:45:00    10.0
# 2010-10-09 16:45:00     5.0
# 2010-10-09 17:45:00    32.0
# 2010-10-09 18:45:00     NaN
# Freq: H, dtype: float64
# -0.1390735939734492
