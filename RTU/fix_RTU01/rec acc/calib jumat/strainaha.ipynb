# %%
import csv
import numpy as np
import struct

filedata = 'save-LOG_-1608276215726'
l=[]  ## empty list
csv_file1=open('../strain/save-LOG_-1608440530621.csv')
temp = csv.reader(csv_file1)
for row in temp:
    time = row[0]
    hasil = row[1]
    ts = struct.unpack('!f', bytes.fromhex(hasil))[0]
#     with open('csvfile.csv','wb') as file:
#         for line in 100:
#             file.write(line)
#             file.write('\n')
    print(time,",",ts)
# Out:
# 2020-12-20T05:02:13.210Z , -961.76806640625
# 2020-12-20T05:02:14.225Z , -961.7820434570312
# 2020-12-20T05:02:15.232Z , -961.8980712890625
# 2020-12-20T05:02:16.334Z , -961.9930419921875
# 2020-12-20T05:02:17.251Z , -961.884033203125
# 2020-12-20T05:02:18.263Z , -961.72802734375
# 2020-12-20T05:02:19.278Z , -961.738037109375
# 2020-12-20T05:02:20.284Z , -961.83203125
# 2020-12-20T05:02:21.294Z , -961.9990234375
# 2020-12-20T05:02:22.306Z , -961.9810180664062
# 2020-12-20T05:02:23.318Z , -961.916015625
# 2020-12-20T05:02:24.327Z , -961.8480224609375
# 2020-12-20T05:02:25.335Z , -961.7730712890625
# 2020-12-20T05:02:26.346Z , -961.716064453125
# 2020-12-20T05:02:27.359Z , -961.6180419921875
# 2020-12-20T05:02:28.371Z , -961.5760498046875
# 2020-12-20T05:02:29.285Z , -961.4130249023438
# 2020-12-20T05:02:30.296Z , -961.3380737304688
# 2020-12-20T05:02:31.307Z , -961.3820190429688
# 2020-12-20T05:02:32.317Z , -961.5670166015625
# 2020-12-20T05:02:33.333Z , -961.8020629882812
# ...

# %%
import pandas as pd

df = pd.read_csv('../strain/save-LOG_-1608440530621.csv')
# time = df['timestamp']
# uss = df['us']


df.plot(x='timestamp')

# %%
import pandas as pd

df = pd.read_csv('../strain/filter.csv')
# time = df['timestamp']
uss = df['us'] * -1


df.plot(y='us')

# %%
import pandas as pd

df = pd.read_csv('05012021.csv')
# time = df['timestamp']
# uss = df['us'] * -1


df.plot(x='timestamp' )

# %%
df = pd.read_csv('06012021.csv')
# time = df['timestamp']
# uss = df['us'] * -1


df.plot(x='timestamp' )

# %%
df = pd.read_csv('07012021.csv')
# time = df['timestamp']
# uss = df['us'] * -1


df.plot(x='timestamp' )

# %%
import pandas as pd
df = pd.read_csv('data/data_10012021.csv')
# time = df['timestamp']
# uss = df['us'] * -1


df.plot(x='timestamp' )

# %%
df = pd.read_csv('data/09012021.csv')
# time = df['timestamp']
# uss = df['us'] * -1


df.plot(x='timestamp' )

# %%
df = pd.read_csv('data/08012021.csv')
# time = df['timestamp']
# uss = df['us'] * -1


df.plot(x='timestamp' )
