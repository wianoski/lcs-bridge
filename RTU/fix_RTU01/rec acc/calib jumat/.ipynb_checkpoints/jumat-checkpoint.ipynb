# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv('27102020_acc1.csv')

# df.to_numpy()
x = df.iloc[:,2::2]
y = df.iloc[:,1::2]

plt.plot(y)

# data = df.plot(x='timestamp')
# data.set_xlabel("RTU Value")

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('filter_acc1.csv', header=None)
a1 = df[1]

for i in range(100):
    i = df[i]
    data = df[i].plot()
    plt.show
#     print(data)
print(timestamp)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-cfe511910a67> in <module>
#       6 for i in range(100):
#       7     i = df[i]
# ----> 8     data = df[i].plot()
#       9     plt.show
#      10 #     print(data)
#
# e:\werk\venv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# e:\werk\venv\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
# ...
