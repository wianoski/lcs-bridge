# %%
from matplotlib import pyplot as plt
from matplotlib import style

from numpy import genfromtxt

data = genfromtxt('6-02_12_2020-strain12.csv',delimiter=',')

plt.plot(data)


plt.xlabel('Timestamp')

plt.show()

# %% [markdown]
# convert here
# http://www.endmemo.com/sconvert/m_s2g.php

# %% [markdown]
# # Inclinometer based on timestamp

# %%
import pandas as pd

df = pd.read_csv('type_2/save-LOG_-1605944953406.csv')
# df.plot(y='pitch')

df1 = pd.read_csv('type_2/save.csv')
# df1.plot(y='pitch')


data = df.plot(x='timestamp')
data.set_xlabel("RTU Value")

data1 = df1.plot(x='timestamp')
data1.set_xlabel("VN100 Value")
# Out:
# Text(0.5, 0, 'VN100 Value')

# %% [markdown]
# # Based on Pitch

# %%
data = df.plot(y='pitch')
data.set_xlabel("RTU Value")

data1 = df1.plot(y='pitch')
data1.set_xlabel("VN100 Value")
# Out:
# Text(0.5, 0, 'VN100 Value')

# %% [markdown]
# # Based on timestamp

# %%
df = pd.read_csv('type_1/save-LOG_-1605943907101.csv')
# df.plot(x='timestamp')

df1 = pd.read_csv('type_1/save_2_1.csv')
# df1.plot(x='timestamp')

data = df.plot(x='timestamp')
data.set_xlabel("RTU Value")

data1 = df1.plot(x='timestamp')
data1.set_xlabel("VN100 Value")
# Out:
# Text(0.5, 0, 'VN100 Value')

# %% [markdown]
# # based on Z axis

# %%
df = pd.read_csv('type_1/save-LOG_-1605943907101.csv')
data = df.plot(y='z')
data.set_xlabel("RTU Value")

df1 = pd.read_csv('type_1/save_2_1.csv')
data1 = df1.plot(y='z')
data1.set_xlabel("VN100 Value")
# Out:
# Text(0.5, 0, 'VN100 Value')

# %%
import struct
import pandas as pd
df = pd.read_csv('strain/save-LOG_-1608095271940.csv')

data = df['hex']
print(data)

data = {'c47c25e4',
         'c47c3324',
         'c47c40c5',
         'c47c45d4',
         'c47c48c5',
         'c47c4a4f',
         'c47c45a3',
         'c47c471b',
         'c47c4917',
         'c47c4a3e',
         'c47c45a3'}

struct.unpack('!f', bytes.fromhex('c47c3324'))[0]

struct.unpack('!f', bytes.fromhex(data))[0]
# Out:
# 0     c47c25e4
# 1     c47c3324
# 2     c47c40c5
# 3     c47c45d4
# 4     c47c48c5
# 5     c47c4a4f
# 6     c47c45a3
# 7     c47c471b
# 8     c47c4917
# 9     c47c4a3e
# 10    c47c45a3
# Name: hex, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-118ecc321fd4> in <module>
#      20 struct.unpack('!f', bytes.fromhex('c47c3324'))[0]
#      21
# ---> 22 struct.unpack('!f', bytes.fromhex(data))[0]
#
# TypeError: fromhex() argument must be str, not set

# %% [markdown]
# mirroring
