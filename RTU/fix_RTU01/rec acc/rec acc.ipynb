# %%
from matplotlib import pyplot as plt
from matplotlib import style

from numpy import genfromtxt

data = genfromtxt('test1_3/test3.csv',delimiter=',')

plt.plot(data)


plt.xlabel('Timestamp')

plt.show()

# %%
import pandas as pd

df = pd.read_csv('test1_3/test3.csv')
df.plot(x='timestamp')

# %%
import pandas as pd

df = pd.read_csv('save-LOG_4.csv')
df.plot(x='timestamp')

# %%
import pandas as pd

#convert here 
#http://www.endmemo.com/sconvert/m_s2g.php#:~:text=%C2%BB%20Acceleration%20of%20gravity%20Conversions%3A,1%20g%20%3D%209.80665%20m%2Fs2

df = pd.read_csv('test_baru_1.csv')
df.plot(x='timestamp')

# %%
from matplotlib import pyplot as plt
from matplotlib import style

from numpy import genfromtxt

data = genfromtxt('save-LOG_3.csv',delimiter=',')

plt.plot(data)


plt.xlabel('Timestamp')

plt.show()
