# %%
from matplotlib import pyplot as plt
from matplotlib import style

from numpy import genfromtxt

data = genfromtxt('test1_3/test3.csv',delimiter=',')

plt.plot(data)


plt.xlabel('Timestamp')

plt.show()

# %% [markdown]
# convert here
# http://www.endmemo.com/sconvert/m_s2g.php

# %%
import pandas as pd

df = pd.read_csv('test1_3/test3.csv')
df.plot(x='timestamp')

# %%
from matplotlib import pyplot as plt
from matplotlib import style

from numpy import genfromtxt

data = genfromtxt('save-LOG_3.csv',delimiter=',')

plt.plot(data)


plt.xlabel('Timestamp')

plt.show()

# %% [markdown]
# # Based on timestamp

# %%
df = pd.read_csv('save-LOG_8.csv')
data = df.plot(x='timestamp')
data.set_xlabel("RTU Value")

df1 = pd.read_csv('test2_4.csv')
data1 = df1.plot(x='timestamp')
data1.set_xlabel("VN100 Value")
# Out:
# Text(0.5, 0, 'VN100 Value')

# %% [markdown]
# # based on X axis

# %%
df = pd.read_csv('save-LOG_8.csv')
data = df.plot(y='z')
data.set_xlabel("RTU Value")

df1 = pd.read_csv('test2_4.csv')
data1 = df1.plot(y='z')
data1.set_xlabel("VN100 Value")
# Out:
# Text(0.5, 0, 'VN100 Value')

# %%
import pandas as pd

df = pd.read_csv('type_1/save-LOG_-1605257844659.csv')
df.plot(y='degree')

# %% [markdown]
# mirroring
