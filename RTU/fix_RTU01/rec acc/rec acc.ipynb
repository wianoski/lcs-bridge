# %%
from matplotlib import pyplot as plt
from matplotlib import style

from numpy import genfromtxt

data = genfromtxt('save-LOG_1.csv',delimiter=',')

plt.plot(data)


plt.xlabel('Timestamp')

plt.show()

# %%
import pandas as pd

df = pd.read_csv('save-LOG_1.csv')
df.plot(x='timestamp')
