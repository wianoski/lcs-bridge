# %%
from matplotlib import pyplot as plt
from matplotlib import style

from numpy import genfromtxt

data = genfromtxt('test1_3/test3.csv',delimiter=',')

plt.plot(data)


plt.xlabel('Timestamp')

plt.show()

# %% [markdown]
# convert here
# http://www.endmemo.com/sconvert/m_s2g.php

# %%
import pandas as pd

df = pd.read_csv('test1_3/test3.csv')
df.plot(x='timestamp')

# %%
from matplotlib import pyplot as plt
from matplotlib import style

from numpy import genfromtxt

data = genfromtxt('save-LOG_3.csv',delimiter=',')

plt.plot(data)


plt.xlabel('Timestamp')

plt.show()

# %%
import pandas as pd

df = pd.read_csv('save-LOG_6.csv')
df.plot(y='x')
df1 = pd.read_csv('test2_2.csv')
df1.plot(y='x')

# %%
df = pd.read_csv('save-LOG_8.csv')
df.plot(y='z')
df1 = pd.read_csv('test2_4.csv')
df1.plot(y='z')

# %% [markdown]
# mirroring

# %%
value = df1.loc[:, ['x', 'y', 'z']]

# print(value)
final = value * -1
print(final)

ahai = pd.DataFrame(final,columns= ['x','y','z'])

ahai.to_csv (r'dataConv.csv', index = False, header=True)
# Out:
#            x       y       z
# 0     0.9873  0.0130 -0.0506
# 1     0.9851  0.0092 -0.0524
# 2     0.9885  0.0114 -0.0486
# 3     0.9880  0.0107 -0.0500
# 4     0.9876  0.0105 -0.0487
# ...      ...     ...     ...
# 5901  0.9859  0.0115 -0.0340
# 5902  0.9870  0.0098 -0.0320
# 5903  0.9887  0.0121 -0.0347
# 5904  0.9870  0.0154 -0.0340
# 5905  0.9871  0.0097 -0.0333
#
# [5906 rows x 3 columns]
